# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df = pd.read_csv('Health_Sleep_Statistics.csv')

# %%
df.head()
# Out:
#    User ID  Age Gender  Sleep Quality Bedtime Wake-up Time  Daily Steps  \
# 0        1   25      f              8   23:00        06:30         8000
# 1        2   34      m              7   00:30        07:00         5000
# 2        3   29      f              9   22:45        06:45         9000
# 3        4   41      m              5   01:00        06:30         4000
# 4        5   22      f              8   23:30        07:00        10000
#
#    Calories Burned Physical Activity Level Dietary Habits Sleep Disorders  \
# 0             2500                  medium        healthy              no
# 1             2200                     low      unhealthy             yes
# 2             2700                    high        healthy              no
# 3             2100                     low      unhealthy             yes
# 4             2800                    high         medium              no
#
#   Medication Usage
# 0               no
# 1              yes
# 2               no
# 3               no
# 4               no
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['User ID'].plot(kind='hist', bins=20, title='User ID')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Age'].plot(kind='hist', bins=20, title='Age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['Sleep Quality'].plot(kind='hist', bins=20, title='Sleep Quality')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['Daily Steps'].plot(kind='hist', bins=20, title='Daily Steps')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_4.groupby('Gender').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_5.groupby('Bedtime').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_6.groupby('Wake-up Time').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_7.groupby('Physical Activity Level').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8.plot(kind='scatter', x='User ID', y='Age', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9.plot(kind='scatter', x='Age', y='Sleep Quality', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_10.plot(kind='scatter', x='Sleep Quality', y='Daily Steps', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_11.plot(kind='scatter', x='Daily Steps', y='Calories Burned', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['User ID']
#   ys = series['Age']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_12.sort_values('User ID', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Gender')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Gender', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('User ID')
# _ = plt.ylabel('Age')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['User ID']
#   ys = series['Age']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_13.sort_values('User ID', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Bedtime')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Bedtime', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('User ID')
# _ = plt.ylabel('Age')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['User ID']
#   ys = series['Age']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_14.sort_values('User ID', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Wake-up Time')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Wake-up Time', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('User ID')
# _ = plt.ylabel('Age')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['User ID']
#   ys = series['Age']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_15.sort_values('User ID', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Physical Activity Level')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Physical Activity Level', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('User ID')
# _ = plt.ylabel('Age')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_16['User ID'].plot(kind='line', figsize=(8, 4), title='User ID')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_17['Age'].plot(kind='line', figsize=(8, 4), title='Age')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_18['Sleep Quality'].plot(kind='line', figsize=(8, 4), title='Sleep Quality')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_19['Daily Steps'].plot(kind='line', figsize=(8, 4), title='Daily Steps')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Bedtime'].value_counts()
#     for x_label, grp in _df_20.groupby('Gender')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Gender')
# _ = plt.ylabel('Bedtime')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Wake-up Time'].value_counts()
#     for x_label, grp in _df_21.groupby('Bedtime')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Bedtime')
# _ = plt.ylabel('Wake-up Time')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Physical Activity Level'].value_counts()
#     for x_label, grp in _df_22.groupby('Wake-up Time')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Wake-up Time')
# _ = plt.ylabel('Physical Activity Level')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Dietary Habits'].value_counts()
#     for x_label, grp in _df_23.groupby('Physical Activity Level')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Physical Activity Level')
# _ = plt.ylabel('Dietary Habits')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_24['Gender'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_24, x='User ID', y='Gender', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_25['Bedtime'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_25, x='User ID', y='Bedtime', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_26['Wake-up Time'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_26, x='User ID', y='Wake-up Time', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_27['Physical Activity Level'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_27, x='User ID', y='Physical Activity Level', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
df.shape
# Out:
# (100, 12)

# %%
df.size
# Out:
# 1200

# %%
df.columns
# Out:
# Index(['User ID', 'Age', 'Gender', 'Sleep Quality', 'Bedtime', 'Wake-up Time',
#        'Daily Steps', 'Calories Burned', 'Physical Activity Level',
#        'Dietary Habits', 'Sleep Disorders', 'Medication Usage'],
#       dtype='object')

# %%
df.columns.size
# Out:
# 12

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   User ID                  100 non-null    int64
#  1   Age                      100 non-null    int64
#  2   Gender                   100 non-null    object
#  3   Sleep Quality            100 non-null    int64
#  4   Bedtime                  100 non-null    object
#  5   Wake-up Time             100 non-null    object
#  6   Daily Steps              100 non-null    int64
#  7   Calories Burned          100 non-null    int64
#  8   Physical Activity Level  100 non-null    object
#  9   Dietary Habits           100 non-null    object
#  10  Sleep Disorders          100 non-null    object
#  11  Medication Usage         100 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 9.5+ KB

# %%
df.describe()
# Out:
#           User ID         Age  Sleep Quality   Daily Steps  Calories Burned
# count  100.000000  100.000000     100.000000    100.000000        100.00000
# mean    50.500000   36.010000       7.000000   6830.000000       2421.00000
# std     29.011492    8.454865       1.734964   2498.706736        281.06759
# min      1.000000   22.000000       4.000000   3000.000000       2000.00000
# 25%     25.750000   28.750000       5.750000   4750.000000       2175.00000
# 50%     50.500000   35.000000       7.500000   6750.000000       2400.00000
# 75%     75.250000   44.000000       8.250000   9000.000000       2700.00000
# max    100.000000   50.000000       9.000000  11000.000000       2900.00000

# %%
df.isna().sum()
# Out:
# User ID                    0
# Age                        0
# Gender                     0
# Sleep Quality              0
# Bedtime                    0
# Wake-up Time               0
# Daily Steps                0
# Calories Burned            0
# Physical Activity Level    0
# Dietary Habits             0
# Sleep Disorders            0
# Medication Usage           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop(['User ID'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    Age Gender  Sleep Quality Bedtime Wake-up Time  Daily Steps  \
# 0   25      f              8   23:00        06:30         8000
# 1   34      m              7   00:30        07:00         5000
# 2   29      f              9   22:45        06:45         9000
# 3   41      m              5   01:00        06:30         4000
# 4   22      f              8   23:30        07:00        10000
#
#    Calories Burned Physical Activity Level Dietary Habits Sleep Disorders  \
# 0             2500                  medium        healthy              no
# 1             2200                     low      unhealthy             yes
# 2             2700                    high        healthy              no
# 3             2100                     low      unhealthy             yes
# 4             2800                    high         medium              no
#
#   Medication Usage
# 0               no
# 1              yes
# 2               no
# 3               no
# 4               no

# %% [markdown]
# ## **Age vs Sleep Quality Analysis**

# %%
age_sleep_quality_corr = df[['Age', 'Sleep Quality']].corr()

# %%
age_sleep_quality_corr
# Out:
#                     Age  Sleep Quality
# Age            1.000000      -0.848356
# Sleep Quality -0.848356       1.000000

# %%
age_sleep_quality_corr['Age']
# Out:
# Age              1.000000
# Sleep Quality   -0.848356
# Name: Age, dtype: float64

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='Age', y='Sleep Quality', data= df)
plt.title('Age vs Sleep Quality Analysis')
plt.xlabel('Age')
plt.ylabel('Sleep Quality')
plt.show()

# %%
from sklearn.linear_model import LinearRegression
age_sleep_quality_model = LinearRegression()

x= df[['Age']]
y= df['Sleep Quality']

age_sleep_quality_model.fit(x,y)
# Out:
# LinearRegression()

# %%
age_sleep_quality_model.intercept_
# Out:
# 13.268812023190648

# %%
age_sleep_quality_model.coef_
# Out:
# array([-0.17408531])

# %%
age_sleep_quality_predictions = age_sleep_quality_model.predict(x)

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x = 'Age', y= 'Sleep Quality',data = df, label= 'Actual Values')
plt.plot(x, age_sleep_quality_predictions, color='green', label='Predicted Values')
plt.legend()
plt.show()

# %% [markdown]
# ## **Physical Activity vs Sleep Quality**

# %%
df['Physical Activity Level'].head()
# Out:
# 0    medium
# 1       low
# 2      high
# 3       low
# 4      high
# Name: Physical Activity Level, dtype: object

# %%
sns.barplot(x='Gender', y= 'Sleep Quality', data =df)
# Out:
# <Axes: xlabel='Gender', ylabel='Sleep Quality'>

# %%
sns.barplot(x='Physical Activity Level', y= 'Sleep Quality', data =df)
# Out:
# <Axes: xlabel='Physical Activity Level', ylabel='Sleep Quality'>

# %%
custom_codes = {'low' : 1, 'medium' : 2, 'high' : 3}
df['Physical Activity Level'] = df['Physical Activity Level'].map(custom_codes)
df['Physical Activity Level'].head()
# Out:
# 0    2
# 1    1
# 2    3
# 3    1
# 4    3
# Name: Physical Activity Level, dtype: int64

# %%
sns.barplot(x='Gender', y='Physical Activity Level', data =df)
# Out:
# <Axes: xlabel='Gender', ylabel='Physical Activity Level'>

# %% [markdown]
# ## **Hypothesis Testing (t-statistic and p-value)**

# %%
#May females sleep better because they exercise more?

# %%
#higher t indicates a more significant diference from the hypothesized mean or between two groups

# %%
from scipy import stats

# %%
sleep_quality_males = df[df['Gender'] == 'm']['Sleep Quality']

# %%
sleep_quality_females = df[df['Gender'] == 'f']['Sleep Quality']

# %%
physical_activity_males = df[df['Gender'] == 'm']['Physical Activity Level']
physical_activity_females = df[df['Gender'] == 'f']['Physical Activity Level']

# %% [markdown]
# ### **Find t and p values for Sleep Quality vs Gender & Physical Activity Level vs Gender**

# %%
t_sleep_quality, p_sleep_quality = stats.ttest_ind(sleep_quality_males, sleep_quality_females)
print(f't_stats value for Sleep Quality vs Gender : {t_sleep_quality:.2f}' )
# Out:
# t_stats value for Sleep Quality vc Gender : -14.32

# %%
print(f'p value for Sleep Quality vs Gender : {p_sleep_quality:.2f}' )
# Out:
# p value for Sleep Quality vc Gender : 0.00

# %%
t_physical_activity, p_physical_activity = stats.ttest_ind(physical_activity_males, physical_activity_females)

print(f't_stats value for Physical Activity vs Gender : {t_physical_activity:.2f}' )
print(f'p value for Physical Activity vs Gender : {p_physical_activity:.2f}' )
# Out:
# t_stats value for Physical Activity vs Gender : -10.98
# p value for Physical Activity vs Gender : 0.00

# %% [markdown]
# ## **Time of Sleep & Waking up vs Sleep Quality**

# %%
df['Bedtime'].head()
# Out:
# 0    23:00
# 1    00:30
# 2    22:45
# 3    01:00
# 4    23:30
# Name: Bedtime, dtype: object

# %%
def sleep_time_helper_function(str_time):
    try:
        # Ensure the time is in "hh:mm" format, and split only once.
        h, m = str_time.split(':')

        # Convert hours and minutes to float.
        return int(h) + int(m) / 60
    except Exception as e:
        print(f"Error processing time: {str_time} | Error: {e}")
        return None  # Return None if there's an issue

# Apply the function to the relevant columns.
df['Bedtime'] = df['Bedtime'].apply(sleep_time_helper_function)
df['Wake-up Time'] = df['Wake-up Time'].apply(sleep_time_helper_function)

# %%
df['Bedtime'].head()
# Out:
# 0    23.00
# 1     0.50
# 2    22.75
# 3     1.00
# 4    23.50
# Name: Bedtime, dtype: float64

# %%
df['Sleep Duration Hours'] = (df['Wake-up Time'] - df['Bedtime']) % 24
df['Sleep Duration Hours'].head()
# Out:
# 0    7.5
# 1    6.5
# 2    8.0
# 3    5.5
# 4    7.5
# Name: Sleep Duration Hours, dtype: float64

# %%
plt.figure(figsize=(12,6))
sns.barplot(x= 'Bedtime', y='Sleep Quality', data=df)
# Out:
# <Axes: xlabel='Bedtime', ylabel='Sleep Quality'>

# %%
plt.figure(figsize=(12,6))
sns.barplot(x= 'Wake-up Time', y='Sleep Quality', data=df)
# Out:
# <Axes: xlabel='Wake-up Time', ylabel='Sleep Quality'>

# %%
plt.figure(figsize=(12,6))
sns.barplot(x= 'Sleep Duration Hours', y='Sleep Quality', data=df)
# Out:
# <Axes: xlabel='Sleep Duration Hours', ylabel='Sleep Quality'>

# %%
sleep_duration_quality_model = LinearRegression()

x= df[['Sleep Duration Hours']]
y=df[['Sleep Quality']]

sleep_duration_quality_model.fit(x,y)
# Out:
# LinearRegression()

# %%
sleep_duration_quality_model.coef_
# Out:
# array([[1.36940999]])

# %%
sleep_duration_quality_model.intercept_
# Out:
# array([-2.57559935])

# %%
predictions = sleep_duration_quality_model.predict(x)
plt.figure(figsize=(12,6))
sns.scatterplot(x='Sleep Duration Hours', y='Sleep Quality', data = df, label= 'Actual values')
plt.plot(x, predictions, color = 'green', label ='Predicted values')
plt.legend()
plt.show()

# %%
df.head()
# Out:
#    Age Gender  Sleep Quality  Bedtime  Wake-up Time  Daily Steps  \
# 0   25      f              8    23.00          6.50         8000
# 1   34      m              7     0.50          7.00         5000
# 2   29      f              9    22.75          6.75         9000
# 3   41      m              5     1.00          6.50         4000
# 4   22      f              8    23.50          7.00        10000
#
#    Calories Burned  Physical Activity Level Dietary Habits Sleep Disorders  \
# 0             2500                        2        healthy              no
# 1             2200                        1      unhealthy             yes
# 2             2700                        3        healthy              no
# 3             2100                        1      unhealthy             yes
# 4             2800                        3         medium              no
#
#   Medication Usage  Sleep Duration Hours
# 0               no                   7.5
# 1              yes                   6.5
# 2               no                   8.0
# 3               no                   5.5
# 4               no                   7.5

# %% [markdown]
# ##**Sleep Disorders vs Sleep Quality**

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='Sleep Disorders', y='Sleep Quality', data=df)
plt.show()

# %%
df_numeric_features = df.select_dtypes(include=['int64','float64'])
df_numeric_features.head()
# Out:
#    Age  Sleep Quality  Bedtime  Wake-up Time  Daily Steps  Calories Burned  \
# 0   25              8    23.00          6.50         8000             2500
# 1   34              7     0.50          7.00         5000             2200
# 2   29              9    22.75          6.75         9000             2700
# 3   41              5     1.00          6.50         4000             2100
# 4   22              8    23.50          7.00        10000             2800
#
#    Physical Activity Level  Sleep Duration Hours
# 0                        2                   7.5
# 1                        1                   6.5
# 2                        3                   8.0
# 3                        1                   5.5
# 4                        3                   7.5

# %% [markdown]
# ##**Sumary**

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df_numeric_features.corr())
plt.show()
